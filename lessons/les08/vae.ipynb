# %% [markdown]
# # Variational AutoEncoder
#
# (https://twitter.com/fchollet)<br>
# Convolutional Variational AutoEncoder (VAE) trained on MNIST digits.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Строим слой семплирования sampling layer

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# ## Строим энкодер encoder

# %%
latent_dim = 2

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 14, 14, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 64)     18496       ['conv2d[0][0]']
#
#  flatten (Flatten)              (None, 3136)         0           ['conv2d_1[0][0]']
#
#  dense (Dense)                  (None, 16)           50192       ['flatten[0][0]']
#
#  z_mean (Dense)                 (None, 2)            34          ['dense[0][0]']
#
#  z_log_var (Dense)              (None, 2)            34          ['dense[0][0]']
#
#  sampling (Sampling)            (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 69,076
# Trainable params: 69,076
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Строим свой decoder

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 64)       36928
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 32)       18464
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 1)        289
#  ranspose)
#
# =================================================================
# Total params: 65,089
# Trainable params: 65,089
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Создаем класс модель по `Model` с особым шагом *обучения* `train_step`

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = encoder(data)
            reconstruction = decoder(z)
            reconstruction_loss = tf.reduce_mean(
                keras.losses.binary_crossentropy(data, reconstruction)
            )
            reconstruction_loss *= 28 * 28
            kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            kl_loss = tf.reduce_mean(kl_loss)
            kl_loss *= -0.5
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }

# %% [markdown]
# ## Учим VAE

# %%
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
vae.fit(mnist_digits, epochs=10, batch_size=128)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 547/547 [==============================] - 21s 19ms/step - loss: 214.1886 - reconstruction_loss: 212.0652 - kl_loss: 2.1234
# Epoch 2/10
# 547/547 [==============================] - 10s 18ms/step - loss: 185.2026 - reconstruction_loss: 182.5051 - kl_loss: 2.6974
# Epoch 3/10
# 547/547 [==============================] - 10s 18ms/step - loss: 167.3664 - reconstruction_loss: 163.5664 - kl_loss: 3.8001
# Epoch 4/10
# 547/547 [==============================] - 10s 18ms/step - loss: 161.8824 - reconstruction_loss: 158.0744 - kl_loss: 3.8081
# Epoch 5/10
# 547/547 [==============================] - 10s 18ms/step - loss: 158.9288 - reconstruction_loss: 155.0668 - kl_loss: 3.8620
# Epoch 6/10
# 547/547 [==============================] - 10s 18ms/step - loss: 156.8208 - reconstruction_loss: 152.9492 - kl_loss: 3.8715
# Epoch 7/10
# 547/547 [==============================] - 10s 18ms/step - loss: 155.3081 - reconstruction_loss: 151.4581 - kl_loss: 3.8499
# Epoch 8/10
# 547/547 [==============================] - 10s 18ms/step - loss: 154.0749 - reconstruction_loss: 150.2292 - kl_loss: 3.8457
# Epoch 9/10
# 547/547 [==============================] - 10s 18ms/step - loss: 153.1284 - reconstruction_loss: 149.3000 - kl_loss: 3.8284
# Epoch 10/10
# 547/547 [==============================] - 10s 18ms/step - loss: 152.4335 - reconstruction_loss: 148.6105 - kl_loss: 3.8230

# %%
vae.fit(mnist_digits, epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 547/547 [==============================] - 10s 18ms/step - loss: 148.5623 - reconstruction_loss: 144.7624 - kl_loss: 3.7998
# Epoch 2/50
# 547/547 [==============================] - 10s 18ms/step - loss: 148.4278 - reconstruction_loss: 144.6103 - kl_loss: 3.8174
# Epoch 3/50
# 547/547 [==============================] - 10s 18ms/step - loss: 148.2262 - reconstruction_loss: 144.4202 - kl_loss: 3.8060
# Epoch 4/50
# 547/547 [==============================] - 10s 18ms/step - loss: 147.9845 - reconstruction_loss: 144.1933 - kl_loss: 3.7912
# Epoch 5/50
# 547/547 [==============================] - 10s 18ms/step - loss: 147.8817 - reconstruction_loss: 144.0762 - kl_loss: 3.8055
# Epoch 6/50
# 547/547 [==============================] - 10s 18ms/step - loss: 147.6433 - reconstruction_loss: 143.8428 - kl_loss: 3.8004
# Epoch 7/50
# 547/547 [==============================] - 10s 18ms/step - loss: 147.5617 - reconstruction_loss: 143.7704 - kl_loss: 3.7913
# Epoch 8/50
# 547/547 [==============================] - 10s 18ms/step - loss: 147.4071 - reconstruction_loss: 143.6099 - kl_loss: 3.7971
# Epoch 9/50
# 547/547 [==============================] - 10s 18ms/step - loss: 147.2652 - reconstruction_loss: 143.4669 - kl_loss: 3.7983
# Epoch 10/50
# 547/547 [==============================] - 10s 18ms/step - loss: 147.1919 - reconstruction_loss: 143.3943 - kl_loss: 3.7976
# Epoch 11/50
# 547/547 [==============================] - 10s 18ms/step - loss: 147.1237 - reconstruction_loss: 143.3327 - kl_loss: 3.7911
# Epoch 12/50
# 547/547 [==============================] - 10s 18ms/step - loss: 146.9873 - reconstruction_loss: 143.1876 - kl_loss: 3.7997
# Epoch 13/50
# 547/547 [==============================] - 10s 18ms/step - loss: 146.8268 - reconstruction_loss: 143.0325 - kl_loss: 3.7943
# Epoch 14/50
# 547/547 [==============================] - 10s 18ms/step - loss: 146.7944 - reconstruction_loss: 142.9932 - kl_loss: 3.8012
# Epoch 15/50
# 547/547 [==============================] - 10s 18ms/step - loss: 146.6255 - reconstruction_loss: 142.8257 - kl_loss: 3.7998
# Epoch 16/50
# 547/547 [==============================] - 10s 18ms/step - loss: 146.5433 - reconstruction_loss: 142.7359 - kl_loss: 3.8074
# Epoch 17/50
# 547/547 [==============================] - 10s 18ms/step - loss: 146.5510 - reconstruction_loss: 142.7418 - kl_loss: 3.8092
# Epoch 18/50
# 547/547 [==============================] - 10s 18ms/step - loss: 146.3259 - reconstruction_loss: 142.5269 - kl_loss: 3.7990
# Epoch 19/50
# 547/547 [==============================] - 10s 18ms/step - loss: 146.2762 - reconstruction_loss: 142.4771 - kl_loss: 3.7991
# Epoch 20/50
# 547/547 [==============================] - 10s 18ms/step - loss: 146.1626 - reconstruction_loss: 142.3611 - kl_loss: 3.8015
# Epoch 21/50
# 547/547 [==============================] - 10s 18ms/step - loss: 146.0926 - reconstruction_loss: 142.2816 - kl_loss: 3.8110
# Epoch 22/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.9709 - reconstruction_loss: 142.1575 - kl_loss: 3.8134
# Epoch 23/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.8930 - reconstruction_loss: 142.0897 - kl_loss: 3.8033
# Epoch 24/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.9361 - reconstruction_loss: 142.1284 - kl_loss: 3.8077
# Epoch 25/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.8469 - reconstruction_loss: 142.0413 - kl_loss: 3.8056
# Epoch 26/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.7761 - reconstruction_loss: 141.9654 - kl_loss: 3.8107
# Epoch 27/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.6492 - reconstruction_loss: 141.8497 - kl_loss: 3.7995
# Epoch 28/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.5901 - reconstruction_loss: 141.7696 - kl_loss: 3.8205
# Epoch 29/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.4641 - reconstruction_loss: 141.6516 - kl_loss: 3.8125
# Epoch 30/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.5078 - reconstruction_loss: 141.6875 - kl_loss: 3.8203
# Epoch 31/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.4831 - reconstruction_loss: 141.6601 - kl_loss: 3.8230
# Epoch 32/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.3051 - reconstruction_loss: 141.4859 - kl_loss: 3.8192
# Epoch 33/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.3090 - reconstruction_loss: 141.4922 - kl_loss: 3.8168
# Epoch 34/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.2364 - reconstruction_loss: 141.4097 - kl_loss: 3.8267
# Epoch 35/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.3089 - reconstruction_loss: 141.4828 - kl_loss: 3.8261
# Epoch 36/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.0422 - reconstruction_loss: 141.2233 - kl_loss: 3.8189
# Epoch 37/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.0703 - reconstruction_loss: 141.2493 - kl_loss: 3.8211
# Epoch 38/50
# 547/547 [==============================] - 10s 18ms/step - loss: 145.1202 - reconstruction_loss: 141.2939 - kl_loss: 3.8263
# Epoch 39/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.9009 - reconstruction_loss: 141.0749 - kl_loss: 3.8260
# Epoch 40/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.9518 - reconstruction_loss: 141.1218 - kl_loss: 3.8300
# Epoch 41/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.9162 - reconstruction_loss: 141.0828 - kl_loss: 3.8333
# Epoch 42/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.8000 - reconstruction_loss: 140.9567 - kl_loss: 3.8433
# Epoch 43/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.7595 - reconstruction_loss: 140.9191 - kl_loss: 3.8404
# Epoch 44/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.7375 - reconstruction_loss: 140.8957 - kl_loss: 3.8419
# Epoch 45/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.7631 - reconstruction_loss: 140.9190 - kl_loss: 3.8441
# Epoch 46/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.6264 - reconstruction_loss: 140.7818 - kl_loss: 3.8446
# Epoch 47/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.7115 - reconstruction_loss: 140.8681 - kl_loss: 3.8434
# Epoch 48/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.5567 - reconstruction_loss: 140.7018 - kl_loss: 3.8549
# Epoch 49/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.4209 - reconstruction_loss: 140.5789 - kl_loss: 3.8420
# Epoch 50/50
# 547/547 [==============================] - 10s 18ms/step - loss: 144.5331 - reconstruction_loss: 140.6894 - kl_loss: 3.8437

# %% [markdown]
# ## Результат предсказания для цифры

# %%
import matplotlib.pyplot as plt


def plot_latent(encoder, decoder):
    # display a n*n 2D manifold of digits
    n = 30
    digit_size = 28
    scale = 2.0
    figsize = 15
    figure = np.zeros((digit_size * n, digit_size * n))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = decoder.predict(z_sample)
            digit = x_decoded[0].reshape(digit_size, digit_size)
            figure[
                i * digit_size : (i + 1) * digit_size,
                j * digit_size : (j + 1) * digit_size,
            ] = digit

    plt.figure(figsize=(figsize, figsize))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range + 1
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent(encoder, decoder)

# %%
x_decoded = decoder.predict([[-1.990,1.5]])
plt.imshow(x_decoded[0,:,:,0] )
plt.show()

# %%
plt.imshow(x_decoded[0,:,:,0] )
plt.show()

# %% [markdown]
# ## Посмотрим на кластеры в скрытом пространстве для цифр

# %%
def plot_label_clusters(encoder, data, labels):
    # display a 2D plot of the digit classes in the latent space
    z_mean, _, _ = encoder.predict(data)
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=labels)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.show()


(x_train, y_train), _ = keras.datasets.mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255

plot_label_clusters(encoder, x_train, y_train)

# %% [markdown]
# Построим немного примеров генерации цифр:
#
# для этого не нужен энкодер
# работа этой модели требует:
# - выбрать случайные значения для точки скрытого пространства (2 координаты (среднее и логарифм от дисперсиии) - для построения в n (в нашем случае 28х28) координаты нового образца )
# - подать их в декодер
# - визуализировать результат

# %%
def plot_digit_from_decoder(decoder, z, digit_size):
    # display a 2D plot of the digit classes in the latent space
    
    data = np.array([[z[0], z[1]]])
    digit = decoder.predict(data)
    digit = digit.reshape(digit_size, digit_size)
    
    plt.figure(figsize=(10, 10))
    plt.imshow(digit)
    plt.colorbar()
    plt.xlabel("x")
    plt.ylabel("y")
    plt.show()



plot_digit_from_decoder(decoder, [-1.5,1.], 28)
